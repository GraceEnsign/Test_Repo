# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Grace Ensign**
# Healthcare Coordinator/Future Data Scientist

# %% [markdown]
# *I am interested in data science because I love solving puzzles. I enjoy working with data of all kinds, and specifically like turning raw data into clean, readable data. I enjoy starting out with a question and working with the data to find the answer. I also like how data can be used across different professions such as entertainment, tech, healthcare, sales, etc. It's a skill that is transferable.*

# %% [markdown]
# ### In the below code I first assigned two variables. Then I used the print function to concatenate the two variables into a short sentence. ###

# %%
a = 'Hey'
b = 'there!'

print(a + ' ' + b)
# Out:
# Hey there!

# %% [markdown]
# > "Colors are the smiles of nature." - Leigh Hunt
#
# 1. Blue
# 2. Orange
# 3. Green
# 4. Purple
# 5. Yellow
# 6. Pink
# 7. Red <br>
# ~~8. Square~~
